# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import requests
import torchvision
import sys
torchvision.disable_beta_transforms_warning()

from PIL import Image
import torchvision.transforms.v2 as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torch import nn
from torchinfo import summary
from tqdm import tqdm
from torchmetrics.classification import MulticlassAccuracy
from sklearn.metrics import accuracy_score

# %%
pd.set_option('display.max_rows', 50)

# %%
torch.__version__
# Out:
# '2.2.1'

# %%
def crop_save_image(row, folder_name:str = 'train'):
    img2 = Image.open(
        os.path.join(os.getcwd(), 'flickr_logos_27_dataset_images', row['file_name'])
    )
    img3 = Image.open(
        os.path.join(os.getcwd(), 'flickr_logos_27_dataset_images', row['file_name'])).crop(
        (row['x1'], row['y1'], row['x2'], row['y2'])
    )
    path = os.path.join(os.getcwd(), folder_name, row['label'], row['file_name'])
    path_cropped = os.path.join(os.getcwd(), folder_name, row['label'],
                                row['file_name'].partition('.')[0]+'_cropped_'+str(row['x1'])+'_'+str(row['y1'])+'.'+row['file_name'].partition('.')[2])
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    try:
        img2.save(path)
        img3.save(path_cropped)
    except:
        os.mkdir(os.path.join(folder_name, row['label']))
        img2.save(path)
        img3.save(path_cropped)
    return os.path.join(folder_name, row['file_name'])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
torch.set_default_device(device)

# %%
def train_step(model: nn.Module, data_loader: torch.utils.data.DataLoader,
               loss_fn: nn.Module, optimizer: torch.optim.Optimizer,
               accuracy_fn):
    train_loss, train_acc = 0, 0
    for batch, (X, y) in enumerate(data_loader):
        y_pred = model(X)
        loss = loss_fn(y_pred, y)        
        train_loss += loss
        train_acc += accuracy_fn(y_pred.argmax(dim=1), y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    train_loss /= len(data_loader)
    train_acc /= len(data_loader)    
    print(f"Train loss: {train_loss:.5f} | Train accuracy: {train_acc*100:.2f}%")
    return train_acc
def test_step(data_loader: torch.utils.data.DataLoader,
              model: nn.Module, loss_fn: nn.Module,
              accuracy_fn):
    test_loss, test_acc = 0, 0
    #model.eval()
    with torch.inference_mode():         
        for X, y in data_loader:
            test_pred = model(X)     
            test_loss += loss_fn(test_pred, y)
            test_acc += accuracy_fn(test_pred.argmax(dim=1), y)
        test_loss /= len(data_loader)
        test_acc /= len(data_loader)        
        print(f"Test loss: {test_loss:.5f} | Test accuracy: {test_acc*100:.2f}%\n")
    return test_acc

# %%
def get_predicted_class(row, class_dict:dict, model:nn.Module, trf):
    with torch.inference_mode():
        im_path = os.path.join('flickr_logos_27_dataset_images', row['file_name'])
        if os.path.isfile(im_path):
            img = trf(Image.open(im_path))
            cls = model(img.unsqueeze(0))
            return class_dict[np.argmax(np.array(cls.cpu()))]
        else:
            return np.nan

# %%
#Clear GPU memory
if device == 'cuda':
    torch.cuda.empty_cache()

# %%
train_img_labels_file = os.path.join(os.getcwd(),
                                    "flickr_logos_27_dataset_training_set_annotation.txt")

train_images = pd.read_csv(train_img_labels_file,
                           sep=' ', 
                           usecols = [i for i in range(7)],
                           header=None,  
                           names=["file_name",'label','subset','x1','y1','x2','y2'])
train_images
# Out:
#            file_name   label  subset   x1   y1   x2   y2
# 0      144503924.jpg  Adidas       1   38   12  234  142
# 1     2451569770.jpg  Adidas       1  242  208  413  331
# 2      390321909.jpg  Adidas       1   13    5   89   60
# 3     4761260517.jpg  Adidas       1   43  122  358  354
# 4     4763210295.jpg  Adidas       1   83   63  130   93
# ...              ...     ...     ...  ...  ...  ...  ...
# 4531  2126991906.jpg   Yahoo       6   15    6  253   54
# 4532   217288720.jpg   Yahoo       6  136  161  304  222
# 4533  2472817996.jpg   Yahoo       6    2    4  499  106
# 4534  2514220918.jpg   Yahoo       6    1   69  342  157
# 4535   386891249.jpg   Yahoo       6  156   10  310   49
#
# [4536 rows x 7 columns]

# %%
len(train_images)
# Out:
# 4536

# %%
test_img_label_file = os.path.join(os.getcwd(),
                                    "flickr_logos_27_dataset_query_set_annotation.txt")

test_images = pd.read_csv(test_img_label_file,
                           sep='\t', 
                            usecols = [i for i in range(2)],
                           header=None,  
                           names=["file_name",'label'])
test_images
# Out:
#           file_name   label
# 0    2403695909.jpg  Adidas
# 1    2912587920.jpg  Adidas
# 2    3441398196.jpg  Adidas
# 3    4605630935.jpg  Adidas
# 4    4606245138.jpg  Adidas
# ..              ...     ...
# 265  3480640208.jpg    none
# 266  3486224308.jpg    none
# 267  3486430785.jpg    none
# 268  3490185235.jpg    none
# 269  3490913574.jpg    none
#
# [270 rows x 2 columns]

# %%
# Training images - with duplicates
plt.figure(figsize=(16, 10))
for idx in range(16):
    ax = plt.subplot(4, 4, idx + 1)
    plt.imshow(Image.open('flickr_logos_27_dataset_images/'+ train_images.loc[idx,'file_name']))
    plt.title(train_images.loc[idx,'label'])
    plt.axis("off")

# %%
diff = set(train_images['label'].unique()).symmetric_difference(set(test_images['label'].unique()))

# %%
#Remove any unrepresented labels
train_images = train_images[train_images['label'].isin(diff) == False]
test_images = test_images[test_images['label'].isin(diff) == False]

# %%
#Subset? There is no apparent use for this column
train_images.drop(columns='subset', inplace=True)

# %%
#So many duplicate images
train_images.drop_duplicates(inplace=True)

# %%
train_images['delta_x'] = train_images['x2'] - train_images['x1']

# %%
train_images['delta_y'] = train_images['y2'] - train_images['y1']

# %%
#Drop images where the logo dimensions are negative
train_images = train_images.drop(
    index = train_images[(train_images['delta_x']<=0) | (train_images['delta_y']<=0)].index)

# %%
train_images = train_images.reset_index()

# %%
# Training images - no duplicates
plt.figure(figsize=(16, 10))
for idx in range(16):
    ax = plt.subplot(4, 4, idx + 1)
    plt.imshow(Image.open('flickr_logos_27_dataset_images/'+ train_images.loc[idx,'file_name']).crop(
        (train_images.loc[idx,'x1'],
         train_images.loc[idx,'y1'],
         train_images.loc[idx,'x2'],
         train_images.loc[idx,'y2'])
    ))
    plt.title(train_images.loc[idx,'label'])
    plt.axis("off")

# %%
#No duplicates in test
test_images = test_images.drop_duplicates(['file_name'])

# %%
test_images
# Out:
#           file_name   label
# 0    2403695909.jpg  Adidas
# 1    2912587920.jpg  Adidas
# 2    3441398196.jpg  Adidas
# 3    4605630935.jpg  Adidas
# 4    4606245138.jpg  Adidas
# ..              ...     ...
# 130  3040021292.jpg     Nbc
# 131   319239030.jpg     Nbc
# 132  3386938907.jpg     Nbc
# 133  3815108969.jpg     Nbc
# 134  4025944647.jpg     Nbc
#
# [135 rows x 2 columns]

# %%
#Crop images to their logo location and save as part of augmentation
train_images['train_path'] = train_images.apply(lambda row: crop_save_image(row, folder_name='train'), axis=1)

# %%
train_images
# Out:
#       index       file_name   label   x1   y1   x2   y2  delta_x  delta_y  \
# 0         0   144503924.jpg  Adidas   38   12  234  142      196      130
# 1         1  2451569770.jpg  Adidas  242  208  413  331      171      123
# 2         2   390321909.jpg  Adidas   13    5   89   60       76       55
# 3         3  4761260517.jpg  Adidas   43  122  358  354      315      232
# 4         4  4763210295.jpg  Adidas   83   63  130   93       47       30
# ...     ...             ...     ...  ...  ...  ...  ...      ...      ...
# 1255   4505  2990076322.jpg   Yahoo   54    2  277   49      223       47
# 1256   4506  3469867139.jpg   Yahoo  108  175  178  201       70       26
# 1257   4507  3469867139.jpg   Yahoo  338  188  424  222       86       34
# 1258   4508  3992886999.jpg   Yahoo   80  194  170  243       90       49
# 1259   4509    82413169.jpg   Yahoo   31    5  228   47      197       42
#
#                 train_path
# 0      train/144503924.jpg
# 1     train/2451569770.jpg
# 2      train/390321909.jpg
# 3     train/4761260517.jpg
# 4     train/4763210295.jpg
# ...                    ...
# 1255  train/2990076322.jpg
# 1256  train/3469867139.jpg
# 1257  train/3469867139.jpg
# 1258  train/3992886999.jpg
# 1259    train/82413169.jpg
#
# [1260 rows x 10 columns]

# %%
class_balance = train_images.groupby('label').count()['file_name']

# %%
print(f'Class representation:\nMin: {class_balance.min()}, Max:{class_balance.max()}')
# Out:
# Class representation:
# Min: 30, Max:100

# %%
#Can be set to max or mean
width, height = round(train_images[['delta_x', 'delta_y']].mean())

# %%
#If needed, we can iterate the resolution
#coeff = 2 is too high - CUDA OOM (>10Gb VRAM taken)
coeff = 1
width, height = int(width*coeff), int(height*coeff)

# %%
width, height
# Out:
# (161, 113)

# %%
#Using v2 transforms is faster and 
train_data_transform = transforms.Compose([
    #Transform to tensor and resize
    transforms.PILToTensor(),
    transforms.Resize((width, height), antialias=True),
    #Augment
    transforms.ColorJitter(),
    transforms.GaussianBlur(3),
    #transforms.RandomRotation(degrees=(0, 30)),
    #transforms.TrivialAugmentWide(num_magnitude_bins=11),
    #transforms.AutoAugment(),
    transforms.RandomPerspective(),
    transforms.RandomPosterize(bits=2),
    transforms.ConvertImageDtype(torch.float32),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
test_data_transform = transforms.Compose([
    transforms.PILToTensor(),
    transforms.Resize((width, height), antialias=True),
    transforms.ConvertImageDtype(torch.float32),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

# %%
train_set_aug = datasets.ImageFolder(root='train', transform=train_data_transform)
test_set = datasets.ImageFolder(root='train', transform=test_data_transform, target_transform=None)

# %%
class_dict = train_set_aug.class_to_idx

# %%
class_dict
# Out:
# {'Adidas': 0,
#  'Apple': 1,
#  'BMW': 2,
#  'Citroen': 3,
#  'Cocacola': 4,
#  'DHL': 5,
#  'Fedex': 6,
#  'Ferrari': 7,
#  'Ford': 8,
#  'Google': 9,
#  'HP': 10,
#  'Heineken': 11,
#  'Intel': 12,
#  'McDonalds': 13,
#  'Mini': 14,
#  'Nbc': 15,
#  'Nike': 16,
#  'Pepsi': 17,
#  'Porsche': 18,
#  'Puma': 19,
#  'RedBull': 20,
#  'Sprite': 21,
#  'Starbucks': 22,
#  'Texaco': 23,
#  'Unicef': 24,
#  'Vodafone': 25,
#  'Yahoo': 26}

# %%
class_dict_inv = {v: k for k, v in class_dict.items()}

# %%
BATCH_SIZE=128

# %%
train_dataloader = DataLoader(dataset=train_set_aug, batch_size=BATCH_SIZE, shuffle=True, generator=torch.Generator(device=device),)
test_dataloader = DataLoader(dataset=test_set, batch_size=BATCH_SIZE, generator=torch.Generator(device=device),)

# %%
next(iter(train_dataloader))[0].cpu().shape
# Out:
# torch.Size([128, 3, 161, 113])

# %%
NUM_CLASSES = len(class_dict)

# %%
NUM_EPOCHS = 30

# %%
#Use if model has been changed or a recompile is needed
REWRITE_MODEL=True

# %%
class ClModel(nn.Module):
    def __init__(self, input_shape=3, hidden_layers=30, output_shape = 3):
        super().__init__()
        self.sequential_model = nn.Sequential(
            nn.Conv2d(input_shape, hidden_layers, kernel_size = 3, stride = 1, padding=1),
            nn.GELU(),
            #nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.Conv2d(hidden_layers, hidden_layers, kernel_size=3, stride=1, padding=1),
            nn.GELU(),
            #nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.Flatten(),
            nn.Dropout(0.3, inplace=True),
            #Change the input shape according to the error output
            nn.Linear(in_features=56000, out_features=500),
            nn.Dropout(0.3, inplace=True),
            #nn.GELU(),
            nn.ReLU(),
            nn.Linear(in_features=500, out_features=output_shape),
            nn.LogSoftmax(dim=1),
            )
    def forward(self, x):
        return self.sequential_model(x)
    
model = ClModel(input_shape = 3, hidden_layers=50, output_shape=NUM_CLASSES)

if os.path.isfile('model.pth') and REWRITE_MODEL==False:
    model.load_state_dict(torch.load('model.pth'))

# %%
torch.compile(model)
# Out:
# OptimizedModule(
#   (_orig_mod): ClModel(
#     (sequential_model): Sequential(
#       (0): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): GELU(approximate='none')
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(50, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): GELU(approximate='none')
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Flatten(start_dim=1, end_dim=-1)
#       (7): Dropout(p=0.3, inplace=True)
#       (8): Linear(in_features=56000, out_features=500, bias=True)
#       (9): Dropout(p=0.3, inplace=True)
#       (10): ReLU()
#       (11): Linear(in_features=500, out_features=27, bias=True)
#       (12): LogSoftmax(dim=1)
#     )
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(),
                             lr=1e-4,
                             weight_decay=1e-5,
                             amsgrad=True,
                            )

# %%
accuracy_fn = MulticlassAccuracy(len(class_dict))

# %%
#Load validation dataset as tensor
val_data_transform = transforms.Compose([
    transforms.PILToTensor(),
    transforms.Resize((width, height), antialias=True),
    transforms.ConvertImageDtype(torch.float32),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

# %%
acc_df = pd.DataFrame({})

# %%
if not os.path.isfile('model.pth') or REWRITE_MODEL:
    for epoch in tqdm(range(NUM_EPOCHS)):
        train_acc = train_step(
            model=model,
            data_loader=train_dataloader,
            loss_fn=loss_fn,
            optimizer=optimizer,
            accuracy_fn=accuracy_fn
            )
        test_acc = test_step(
            model=model,
            data_loader=train_dataloader,
            loss_fn=loss_fn,
            accuracy_fn=accuracy_fn
            )
        test_images['pred_label'] = test_images.apply(
            lambda row: get_predicted_class(row, class_dict=class_dict_inv, model=model, trf=val_data_transform),
            axis=1)
        real_acc = accuracy_score(test_images['label'], test_images['pred_label'])
        print(f'Real accuracy: {real_acc:.2f}')
        acc_df = pd.concat([acc_df, pd.DataFrame({'epoch':epoch, 'train_acc':train_acc.cpu().numpy(), "test_acc":test_acc.cpu().numpy(), 'val_acc':real_acc}, index=[0])])
    torch.save(model.state_dict(), os.path.join(os.getcwd(), 'model.pth'))
else:
    test_images['pred_label'] = test_images.apply(
            lambda row: get_predicted_class(row, class_dict=class_dict_inv, model=model, trf=val_data_transform),
            axis=1)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Train loss: 3.13176 | Train accuracy: 10.89%
# Test loss: 2.85785 | Test accuracy: 17.50%
#   3%|▎         | 1/30 [00:09<04:27,  9.24s/it]
# Real accuracy: 0.10
# Train loss: 2.68683 | Train accuracy: 21.97%
# Test loss: 2.52202 | Test accuracy: 28.55%
#   7%|▋         | 2/30 [00:18<04:12,  9.01s/it]
# Real accuracy: 0.16
# Train loss: 2.43586 | Train accuracy: 31.92%
# Test loss: 2.24819 | Test accuracy: 35.79%
#  10%|█         | 3/30 [00:26<04:01,  8.95s/it]
# Real accuracy: 0.21
# Train loss: 2.20857 | Train accuracy: 37.48%
# Test loss: 2.05275 | Test accuracy: 43.79%
#  13%|█▎        | 4/30 [00:35<03:52,  8.94s/it]
# Real accuracy: 0.25
# Train loss: 2.02384 | Train accuracy: 44.14%
# Test loss: 1.88319 | Test accuracy: 46.07%
#  17%|█▋        | 5/30 [00:44<03:42,  8.90s/it]
# Real accuracy: 0.28
# Train loss: 1.90132 | Train accuracy: 45.55%
# Test loss: 1.77403 | Test accuracy: 50.42%
#  20%|██        | 6/30 [00:53<03:33,  8.89s/it]
# Real accuracy: 0.30
# Train loss: 1.81108 | Train accuracy: 49.34%
# Test loss: 1.68216 | Test accuracy: 52.18%
#  23%|██▎       | 7/30 [01:02<03:24,  8.90s/it]
# Real accuracy: 0.29
# Train loss: 1.68838 | Train accuracy: 52.71%
# Test loss: 1.62142 | Test accuracy: 54.19%
#  27%|██▋       | 8/30 [01:11<03:16,  8.95s/it]
# Real accuracy: 0.33
# Train loss: 1.63812 | Train accuracy: 52.28%
# Test loss: 1.50876 | Test accuracy: 55.94%
#  30%|███       | 9/30 [01:20<03:09,  9.01s/it]
# Real accuracy: 0.30
# Train loss: 1.49323 | Train accuracy: 57.16%
# Test loss: 1.44865 | Test accuracy: 58.13%
#  33%|███▎      | 10/30 [01:29<03:00,  9.04s/it]
# Real accuracy: 0.30
# Train loss: 1.46652 | Train accuracy: 59.15%
# Test loss: 1.39120 | Test accuracy: 59.77%
#  37%|███▋      | 11/30 [01:38<02:51,  9.00s/it]
# Real accuracy: 0.36
# Train loss: 1.39961 | Train accuracy: 60.44%
# Test loss: 1.28894 | Test accuracy: 63.77%
#  40%|████      | 12/30 [01:47<02:41,  8.97s/it]
# Real accuracy: 0.34
# Train loss: 1.33361 | Train accuracy: 59.98%
# Test loss: 1.22007 | Test accuracy: 64.27%
#  43%|████▎     | 13/30 [01:56<02:32,  8.95s/it]
# Real accuracy: 0.33
# Train loss: 1.28684 | Train accuracy: 65.26%
# Test loss: 1.21144 | Test accuracy: 66.27%
#  47%|████▋     | 14/30 [02:05<02:22,  8.93s/it]
# Real accuracy: 0.37
# Train loss: 1.29808 | Train accuracy: 62.85%
# Test loss: 1.11004 | Test accuracy: 69.16%
#  50%|█████     | 15/30 [02:14<02:13,  8.90s/it]
# Real accuracy: 0.35
# Train loss: 1.16124 | Train accuracy: 66.84%
# Test loss: 1.09507 | Test accuracy: 69.96%
#  53%|█████▎    | 16/30 [02:23<02:04,  8.89s/it]
# Real accuracy: 0.38
# Train loss: 1.12446 | Train accuracy: 68.69%
# Test loss: 1.08343 | Test accuracy: 68.89%
#  57%|█████▋    | 17/30 [02:31<01:55,  8.86s/it]
# Real accuracy: 0.32
# Train loss: 1.11124 | Train accuracy: 68.93%
# Test loss: 1.04805 | Test accuracy: 70.87%
#  60%|██████    | 18/30 [02:40<01:46,  8.86s/it]
# Real accuracy: 0.38
# Train loss: 1.03359 | Train accuracy: 70.44%
# Test loss: 0.93992 | Test accuracy: 72.93%
#  63%|██████▎   | 19/30 [02:49<01:37,  8.85s/it]
# Real accuracy: 0.38
# Train loss: 1.01497 | Train accuracy: 70.89%
# Test loss: 0.95223 | Test accuracy: 72.80%
#  67%|██████▋   | 20/30 [02:58<01:29,  8.91s/it]
# Real accuracy: 0.34
# Train loss: 0.94491 | Train accuracy: 71.72%
# Test loss: 0.90611 | Test accuracy: 75.38%
#  70%|███████   | 21/30 [03:07<01:20,  8.92s/it]
# Real accuracy: 0.32
# Train loss: 0.95632 | Train accuracy: 73.76%
# Test loss: 0.90620 | Test accuracy: 74.13%
#  73%|███████▎  | 22/30 [03:16<01:11,  8.93s/it]
# Real accuracy: 0.37
# Train loss: 0.91523 | Train accuracy: 74.62%
# Test loss: 0.91201 | Test accuracy: 73.88%
#  77%|███████▋  | 23/30 [03:25<01:02,  8.92s/it]
# Real accuracy: 0.36
# Train loss: 0.87019 | Train accuracy: 74.88%
# Test loss: 0.84904 | Test accuracy: 75.42%
#  80%|████████  | 24/30 [03:34<00:53,  8.96s/it]
# Real accuracy: 0.35
# Train loss: 0.86312 | Train accuracy: 74.43%
# Test loss: 0.82497 | Test accuracy: 75.82%
#  83%|████████▎ | 25/30 [03:43<00:44,  8.92s/it]
# Real accuracy: 0.39
# Train loss: 0.80766 | Train accuracy: 77.10%
# Test loss: 0.81404 | Test accuracy: 77.21%
#  87%|████████▋ | 26/30 [03:52<00:35,  8.89s/it]
# Real accuracy: 0.36
# Train loss: 0.84377 | Train accuracy: 76.51%
# Test loss: 0.80488 | Test accuracy: 74.10%
#  90%|█████████ | 27/30 [04:01<00:26,  8.89s/it]
# Real accuracy: 0.40
# Train loss: 0.78803 | Train accuracy: 77.71%
# Test loss: 0.74491 | Test accuracy: 77.92%
#  93%|█████████▎| 28/30 [04:09<00:17,  8.90s/it]
# Real accuracy: 0.40
# Train loss: 0.76607 | Train accuracy: 77.61%
# Test loss: 0.72252 | Test accuracy: 79.85%
#  97%|█████████▋| 29/30 [04:18<00:08,  8.88s/it]
# Real accuracy: 0.40
# Train loss: 0.75783 | Train accuracy: 78.64%
# Test loss: 0.66969 | Test accuracy: 80.53%
# 100%|██████████| 30/30 [04:27<00:00,  8.92s/it]
# Real accuracy: 0.40

# %%
test_images
# Out:
#           file_name   label pred_label
# 0    2403695909.jpg  Adidas       Puma
# 1    2912587920.jpg  Adidas     Sprite
# 2    3441398196.jpg  Adidas  McDonalds
# 3    4605630935.jpg  Adidas      Fedex
# 4    4606245138.jpg  Adidas  Starbucks
# ..              ...     ...        ...
# 130  3040021292.jpg     Nbc        Nbc
# 131   319239030.jpg     Nbc       Ford
# 132  3386938907.jpg     Nbc        Nbc
# 133  3815108969.jpg     Nbc      Yahoo
# 134  4025944647.jpg     Nbc        Nbc
#
# [135 rows x 3 columns]

# %%
# Training images - no duplicates
plt.figure(figsize=(16, 10))
for idx in range(16):
    ax = plt.subplot(4, 4, idx + 1)
    plt.imshow(Image.open('flickr_logos_27_dataset_images/'+ test_images.loc[idx,'file_name']))
    label = test_images.loc[idx,'label']
    pred_label = test_images.loc[idx,'pred_label']
    plt.title(f'Test:{label}, pred: {pred_label}')
    plt.axis("off")

# %%
# Training images - no duplicates - 2nd
plt.figure(figsize=(16, 10))
for idx in np.arange(0, 16):
    ax = plt.subplot(4, 4, idx + 1)
    idx+=16
    plt.imshow(Image.open('flickr_logos_27_dataset_images/'+ test_images.loc[idx,'file_name']))
    label = test_images.loc[idx,'label']
    pred_label = test_images.loc[idx,'pred_label']
    plt.title(f'Test:{label}, pred: {pred_label}')
    plt.axis("off")

# %%
#acc_df

# %%
plt.xlim([0, NUM_EPOCHS])
plt.ylim([0,1])
ax = sns.lineplot(data=acc_df, x='epoch', y='train_acc', legend='brief', label='train_acc')
sns.lineplot(data=acc_df, x='epoch', y='test_acc', ax=ax, legend='brief', label='test_acc')
sns.lineplot(data=acc_df, x='epoch', y='val_acc', ax=ax, legend='brief', label='val_acc')
plt.grid()
plt.show()
# Out:
# /home/eugen/anaconda3/envs/tfv2/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/eugen/anaconda3/envs/tfv2/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/eugen/anaconda3/envs/tfv2/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/eugen/anaconda3/envs/tfv2/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/eugen/anaconda3/envs/tfv2/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/eugen/anaconda3/envs/tfv2/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#ax.get_figure().savefig('accuracy_VGG.png', bbox_inches='tight')

# %%
#Load model - final cell

class ClModel(nn.Module):
    def __init__(self, input_shape=3, hidden_layers=30, output_shape = 3):
        super().__init__()
        self.sequential_model = nn.Sequential(
            nn.Conv2d(input_shape, hidden_layers, kernel_size = 3, stride = 1, padding=1),
            nn.GELU(),
            #nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.Conv2d(hidden_layers, hidden_layers, kernel_size=3, stride=1, padding=1),
            nn.GELU(),
            #nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False),
            nn.Flatten(),
            nn.Dropout(0.3, inplace=True),
            #Change the input shape according to the error output
            nn.Linear(in_features=56000, out_features=500),
            nn.Dropout(0.3, inplace=True),
            #nn.GELU(),
            nn.ReLU(),
            nn.Linear(in_features=500, out_features=output_shape),
            nn.LogSoftmax(dim=1),
            )
    def forward(self, x):
        return self.sequential_model(x)
    
model = ClModel(input_shape = 3, hidden_layers=50, output_shape=NUM_CLASSES)
#Independent class dict load:
class_dict_inv = {0: 'Adidas',
 1: 'Apple',
 2: 'BMW',
 3: 'Citroen',
 4: 'Cocacola',
 5: 'DHL',
 6: 'Fedex',
 7: 'Ferrari',
 8: 'Ford',
 9: 'Google',
 10: 'HP',
 11: 'Heineken',
 12: 'Intel',
 13: 'McDonalds',
 14: 'Mini',
 15: 'Nbc',
 16: 'Nike',
 17: 'Pepsi',
 18: 'Porsche',
 19: 'Puma',
 20: 'RedBull',
 21: 'Sprite',
 22: 'Starbucks',
 23: 'Texaco',
 24: 'Unicef',
 25: 'Vodafone',
 26: 'Yahoo'}
#Data transform for validation set (simple load as tensor):
val_data_transform = transforms.Compose([
    transforms.PILToTensor(),
    transforms.Resize((161, 113), antialias=True),
    transforms.ConvertImageDtype(torch.float32),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
#Load model state dict:
model.load_state_dict(torch.load('model.pth'))
#Show model structure:
model.eval()
#To check predictions on any validation set of form [link, label]:
test_images.apply(
            lambda row: get_predicted_class(row, class_dict=class_dict_inv, model=model, trf=val_data_transform),
            axis=1)
test_images
# Out:
#           file_name   label pred_label
# 0    2403695909.jpg  Adidas       Puma
# 1    2912587920.jpg  Adidas     Sprite
# 2    3441398196.jpg  Adidas  McDonalds
# 3    4605630935.jpg  Adidas      Fedex
# 4    4606245138.jpg  Adidas  Starbucks
# ..              ...     ...        ...
# 130  3040021292.jpg     Nbc        Nbc
# 131   319239030.jpg     Nbc       Ford
# 132  3386938907.jpg     Nbc        Nbc
# 133  3815108969.jpg     Nbc      Yahoo
# 134  4025944647.jpg     Nbc        Nbc
#
# [135 rows x 3 columns]
