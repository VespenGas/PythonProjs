# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.grid()

# %%
df = pd.read_csv('df_k_means_metrics.csv', index_col=None)

# %%
df = df[df.columns[1:]]

# %%
df
# Out:
#     number_of_clients  number_of_clusters  silhouette_score  \
# 0            100000.0                 3.0          0.724364
# 1            100000.0                 8.0          0.623284
# 2            100000.0                13.0          0.617528
# 3            100000.0                18.0          0.471097
# 4            100000.0                23.0          0.498467
# 5            100000.0                28.0          0.511880
# 6            100000.0                33.0          0.445411
# 7            100000.0                38.0          0.446117
# 8            100000.0                43.0          0.474172
# 9            100000.0                48.0          0.478979
# 10           100000.0                53.0          0.477284
# 11           100000.0                58.0          0.487437
# 12           100000.0                63.0          0.484842
# 13           100000.0                68.0          0.487989
# 14           100000.0                73.0          0.491054
# ...

# %%
sns.lineplot(data=df, x=df.index, y=df.silhouette_score)
# Out:
# <Axes: ylabel='silhouette_score'>
