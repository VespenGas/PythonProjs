# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ast
import numpy as np

# %%
df = pd.read_csv('df_k_means_metrics.csv', index_col=None)

# %%
df = df[df.columns[1:]]

# %%
df
# Out:
#      data_fraction_ID  number_of_clients_fractured  number_of_clusters  \
# 0                   0                       293215                 325
# 1                   0                       293215                 326
# 2                   0                       293215                 327
# 3                   0                       293215                 328
# 4                   0                       293215                 329
# ..                ...                          ...                 ...
# 315                15                       293215                 340
# 316                15                       293215                 341
# 317                15                       293215                 342
# 318                15                       293215                 343
# 319                15                       293215                 344
#
#      silhouette_score  calinski_harabasz_score  davies_bouldin_score  \
# 0            0.473266             1.448680e+06              0.621588
# 1            0.475447             1.460719e+06              0.628884
# 2            0.461157             1.459328e+06              0.629465
# 3            0.472839             1.444253e+06              0.636648
# 4            0.467997             1.460519e+06              0.628930
# ..                ...                      ...                   ...
# 315          0.472756             1.498637e+06              0.623354
# 316          0.475559             1.468164e+06              0.632238
# 317          0.463587             1.495430e+06              0.624823
# 318          0.468938             1.489103e+06              0.627186
# 319          0.469418             1.483836e+06              0.631085
#
#                                         cluster_center
# 0    [[151.34500244 -33.4153284 ]\n [152.93093959 -...
# 1    [[150.87917682 -34.43862555]\n [152.9178915  -...
# 2    [[150.44702835 -33.72014927]\n [152.70564215 -...
# 3    [[151.12870859 -33.96094545]\n [152.84857804 -...
# 4    [[153.43915965 -28.83887683]\n [150.57831957 -...
# ..                                                 ...
# 315  [[147.83571325 -34.02915623]\n [151.28657754 -...
# 316  [[150.88946992 -33.73241098]\n [153.45390501 -...
# 317  [[151.01937654 -34.04176172]\n [152.91476894 -...
# 318  [[151.23813724 -33.93897816]\n [151.11289434 -...
# 319  [[151.14576996 -33.74485039]\n [153.17363867 -...
#
# [320 rows x 7 columns]

# %%
df['number_of_clusters'].max()
# Out:
# 344

# %%
sns.lineplot(data=df, x=df.number_of_clusters, y=df.silhouette_score, label='Silhouette')
sns.lineplot(data=df, x=df.number_of_clusters, y=df.davies_bouldin_score, label='Davies')
plt.ylabel('score')
plt.ylim([0,1])
plt.xlim(df['number_of_clusters'].min(), df['number_of_clusters'].max())
plt.grid()
plt.show()

# %%
df['cluster_center'] = df['cluster_center'].str.replace('\n', ',')

# %%
df['cluster_center'] = df['cluster_center'].transform(lambda x: ' '.join(x.split())).str.replace(' ]', ']')

# %%
df['cluster_center'] = df['cluster_center'].str.replace(' ', ', ').str.replace(',,', ',').transform(lambda x: ast.literal_eval(x))

# %%
assert df['number_of_clients_fractured'].max()==df['number_of_clients_fractured'].min(), 'Asymmetric fractures detected'

# %%
df.sort_values(by=['silhouette_score'], ascending=False)
# Out:
#      data_fraction_ID  number_of_clients_fractured  number_of_clusters  \
# 115                 5                       293215                 340
# 307                15                       293215                 332
# 32                  1                       293215                 337
# 131                 6                       293215                 336
# 48                  2                       293215                 333
# ..                ...                          ...                 ...
# 51                  2                       293215                 336
# 6                   0                       293215                 331
# 217                10                       293215                 342
# 225                11                       293215                 330
# 197                 9                       293215                 342
#
#      silhouette_score  calinski_harabasz_score  davies_bouldin_score  \
# 115          0.484983             1.486339e+06              0.627262
# 307          0.483536             1.501575e+06              0.609330
# 32           0.482354             1.459387e+06              0.634344
# 131          0.481669             1.465810e+06              0.626968
# 48           0.481667             1.463973e+06              0.628020
# ..                ...                      ...                   ...
# 51           0.459693             1.464669e+06              0.630043
# 6            0.458794             1.437327e+06              0.638473
# 217          0.458049             1.467764e+06              0.620627
# 225          0.458008             1.396013e+06              0.634767
# 197          0.456228             1.449984e+06              0.643798
#
#                                         cluster_center
# 115  [[152.14771716, -32.70979018], [151.17810833, ...
# 307  [[150.8159066, -34.48223819], [152.95966898, -...
# 32   [[151.10447321, -33.71075932], [151.11786323, ...
# 131  [[151.08283399, -34.02714905], [153.10207163, ...
# 48   [[151.12261468, -34.04215989], [152.55101507, ...
# ..                                                 ...
# 51   [[150.78029984, -33.77746498], [153.17327537, ...
# 6    [[151.00721267, -33.81185501], [153.51105218, ...
# 217  [[151.32356462, -33.50969269], [152.93505848, ...
# 225  [[151.36914438, -32.66977139], [151.01906421, ...
# 197  [[146.64134696, -35.95690846], [151.20970116, ...
#
# [320 rows x 7 columns]

# %%
analysis_df = df.drop(columns=['data_fraction_ID', 'number_of_clients_fractured', 'cluster_center']).groupby(['number_of_clusters']).mean()

# %%
analysis_df
# Out:
#                     silhouette_score  calinski_harabasz_score  \
# number_of_clusters
# 325                         0.469623             1.442096e+06
# 326                         0.471994             1.447651e+06
# 327                         0.470177             1.450318e+06
# 328                         0.473479             1.445332e+06
# 329                         0.471313             1.450540e+06
# 330                         0.468907             1.448454e+06
# 331                         0.471184             1.451893e+06
# 332                         0.469737             1.452106e+06
# 333                         0.473886             1.459529e+06
# 334                         0.472419             1.458211e+06
# 335                         0.470485             1.457302e+06
# 336                         0.471980             1.459772e+06
# 337                         0.472807             1.462164e+06
# 338                         0.471088             1.461266e+06
# 339                         0.471705             1.464852e+06
# 340                         0.470727             1.466959e+06
# 341                         0.471402             1.468553e+06
# 342                         0.470098             1.469261e+06
# 343                         0.470490             1.470362e+06
# 344                         0.470784             1.474288e+06
#
#                     davies_bouldin_score
# number_of_clusters
# 325                             0.626657
# 326                             0.626426
# 327                             0.626777
# 328                             0.628754
# 329                             0.627315
# 330                             0.631212
# 331                             0.625925
# 332                             0.628797
# 333                             0.627404
# 334                             0.628137
# 335                             0.630053
# 336                             0.627047
# 337                             0.626073
# 338                             0.630500
# 339                             0.625316
# 340                             0.629681
# 341                             0.628845
# 342                             0.629403
# 343                             0.628787
# 344                             0.629164

# %%
df.to_csv('df_k_means_metrics_fixed.csv')

# %%
df
# Out:
#      data_fraction_ID  number_of_clients_fractured  number_of_clusters  \
# 0                   0                       293215                 325
# 1                   0                       293215                 326
# 2                   0                       293215                 327
# 3                   0                       293215                 328
# 4                   0                       293215                 329
# ..                ...                          ...                 ...
# 315                15                       293215                 340
# 316                15                       293215                 341
# 317                15                       293215                 342
# 318                15                       293215                 343
# 319                15                       293215                 344
#
#      silhouette_score  calinski_harabasz_score  davies_bouldin_score  \
# 0            0.473266             1.448680e+06              0.621588
# 1            0.475447             1.460719e+06              0.628884
# 2            0.461157             1.459328e+06              0.629465
# 3            0.472839             1.444253e+06              0.636648
# 4            0.467997             1.460519e+06              0.628930
# ..                ...                      ...                   ...
# 315          0.472756             1.498637e+06              0.623354
# 316          0.475559             1.468164e+06              0.632238
# 317          0.463587             1.495430e+06              0.624823
# 318          0.468938             1.489103e+06              0.627186
# 319          0.469418             1.483836e+06              0.631085
#
#                                         cluster_center
# 0    [[151.34500244, -33.4153284], [152.93093959, -...
# 1    [[150.87917682, -34.43862555], [152.9178915, -...
# 2    [[150.44702835, -33.72014927], [152.70564215, ...
# 3    [[151.12870859, -33.96094545], [152.84857804, ...
# 4    [[153.43915965, -28.83887683], [150.57831957, ...
# ..                                                 ...
# 315  [[147.83571325, -34.02915623], [151.28657754, ...
# 316  [[150.88946992, -33.73241098], [153.45390501, ...
# 317  [[151.01937654, -34.04176172], [152.91476894, ...
# 318  [[151.23813724, -33.93897816], [151.11289434, ...
# 319  [[151.14576996, -33.74485039], [153.17363867, ...
#
# [320 rows x 7 columns]

# %%
df_predicted_result = pd.DataFrame(list(df[df['number_of_clusters']==335].sample(1)['cluster_center'])[0], columns=[['lon', 'lat']])

# %%
df_predicted_result
# Out:
#             lon        lat
# 0    151.166423 -33.745994
# 1    152.912882 -29.696661
# 2    147.590479 -34.871245
# 3    150.659436 -32.380837
# 4    150.623005 -35.100784
# ..          ...        ...
# 330  149.081300 -33.657927
# 331  148.180434 -35.541215
# 332  149.270318 -33.543997
# 333  149.315925 -34.133651
# 334  148.539317 -29.516886
#
# [335 rows x 2 columns]

# %%
df_predicted_result.to_csv('predicted_result_plot.csv')
